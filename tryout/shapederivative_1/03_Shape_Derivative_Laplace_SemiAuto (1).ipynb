# %% [markdown]
# # 7.3 PDE-Constrained Shape Optimization (semi-automated)

# %% [markdown]
# We want to solve the PDE-constrained shape optimization problem
# $$
#             \underset{\Omega\subset \mathsf{D}}{\mbox{min}} \; J(u) := \int_\Omega |u-u_d|^q \; dx, \quad q\ge 2
# $$
#  subject to that $(\Omega,u)$ satisfy
#  $$
#            \int_\Omega \nabla u \cdot \nabla v \; dx = \int_\Omega f v \; dx \; \quad \text{ for all } v \in H_0^1(\Omega),
# $$
# where $\Omega \subset \mathbb R^2$ for given $u_d, \, f \in C^1(\mathbb R^2)$.
#
# Here, we want to compute the shape derivative by differentiation of a suitably defined perturbed Lagrangian using automated differentiation. For details we refer to
#
# P. Gangl, K. Sturm, M. Neunteufel, J. Schöberl.
# Fully and Semi-Automated Shape Differentiation in NGSolve,
# Struct. Multidisc. Optim., 63, pp.1579-1607, 2021.

# %%
from ngsolve import *
from ngsolve.webgui import Draw
from netgen.geom2d import SplineGeometry

# %%
geo = SplineGeometry()
geo.AddCircle(c=(0.5,0.5), r=0.5, bc = 'circle')
mesh = Mesh(geo.GenerateMesh(maxh = 0.08))

# %%
#given data of our problem (chosen such that \Omega^* = [0,1]^2 is the optimal shape)
f = CoefficientFunction(2*y*(1-y)+2*x*(1-x))
ud = x*(1-x)*y*(1-y)

grad_f = CoefficientFunction( (f.Diff(x), f.Diff(y) ) )
grad_ud = CoefficientFunction( (ud.Diff(x), ud.Diff(y) ) )

# %% [markdown]
# ### State equation

# %%
fes = H1(mesh, order=2, dirichlet=".*")
u, v = fes.TnT()
gfu = GridFunction(fes)
scene = Draw(gfu, mesh, "state")

a = BilinearForm(fes, symmetric=True)
a += grad(u)*grad(v)*dx

fstate = LinearForm(fes)
fstate += f*v*dx
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2201', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, 'draw_vol': Fals…

# %%
def SolveStateEquation():
    rhs = gfu.vec.CreateVector()
    rhs.data = fstate.vec - a.mat * gfu.vec
    update = gfu.vec.CreateVector()
    update.data = a.mat.Inverse(fes.FreeDofs()) * rhs
    gfu.vec.data += update

# %%
a.Assemble()
fstate.Assemble()
SolveStateEquation()

scene.Redraw()

# %% [markdown]
# ### Adjoint equation

# %% [markdown]
# We set up the adjoint equation
# $$
#     \mbox{Find } p \in H_0^1(\Omega): \int_\Omega \nabla w \cdot \nabla p \, \mbox dx = - \partial_u J(u)(w) \quad \text{ for all } w \in H_0^1(\Omega)
# $$
# where $u$ is the solution to the state equation. For $J(u) = \int_\Omega |u-u_d|^q \mbox dx$, we get
# $$
#     \partial_u J(u)(w) = q \int_\Omega (u-u_d)^{d-1}w \,\mbox dx.
# $$
# However, we can also use the Diff(...) command:

# %%
q=4
def Cost(u): 
    return (u-ud)**q*dx

p, w = fes.TnT()
gfp = GridFunction(fes)
scene = Draw (gfp, mesh, "adjoint")

fadjoint = LinearForm(fes)
fadjoint += -1*Cost(gfu).Diff(gfu,w)
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2201', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, 'draw_vol': Fals…

# %%
def SolveAdjointEquation():
    rhs = gfp.vec.CreateVector()
    rhs.data = fadjoint.vec - a.mat.T * gfp.vec
    update = gfp.vec.CreateVector()
    update.data = a.mat.Inverse(fes.FreeDofs()).T * rhs
    gfp.vec.data += update

# %%
fadjoint.Assemble()
SolveAdjointEquation()
scene.Redraw()

# %% [markdown]
# Note that (for linear problems) the operator on the left hand side of the adjoint equation is just the transpose of the state operator.

# %% [markdown]
# ### Automatic Shape Differentiation

# %% [markdown]
# The formula for the shape derivative was derived as the partial derivative of the perturbed Lagrangian (brought back to the original domain):
# $$
#     d\mathcal J(\Omega; X) = \frac{\partial}{\partial t} \left. \left( \int_\Omega \xi(t)|u - u_d^t|^q \mbox{d} x
#          +  \int_{\Omega} (F_t^{-\top}\nabla u) \cdot (F_t^{-\top} \nabla p) \xi(t) \, dx - \int_{\Omega} \xi(t) f^t p \,dx \right) \right\rvert_{t=0}
# $$
# where
# <ul>
#     <li>   $T_t(x)=x+tX(x)=y$
#     <li> $F_t = DT_t = I+t DX$
#     <li> $\xi(t) = \mbox{det}(F_t)$
#     <li>  $u_d^t = u_d \circ T_t$
#     <li> $f^t = f \circ T_t$
# </ul>
#
# The integrand depends on the parameter $t$ only via $\xi(t)$, $F_t$ and $T_t$. Denoting the integrand by $G^{u,p}$, the derivative is given by
# $$
# \begin{array}{rl}
#      d\mathcal J(\Omega; X) =& \frac{d G^{u,p}}{d \xi} \frac{d \xi}{d t} + \frac{d  G^{u,p}}{d F} \frac{d F}{d t} + \frac{d  G^{u,p}}{dy} \cdot \frac{d T_t}{dt} \\
#      =& \frac{d G^{u,p}}{d \xi} \mbox{div}(X) + \frac{d  G^{u,p}}{d F} DX + \frac{d  G^{u,p}}{dy} \cdot X
# \end{array}
# $$

# %% [markdown]
# We define the perturbed PDE and cost function involving parameters $F$ and $J$ representing the Jacobian of a shape transformation and its determinant, respectively. While their values are set to unity and thus does not influence the solution of the state or adjoint equation, this procedure allows us to differentiate with respect to them.

# %%
J = Parameter(1)
F = Id(2)
#Finv = 2*Id(2) - F    # consistent linearization at F = I (avoids calling Inv() for speedup)

def Equation(u,v):
    return ( (Inv(F.trans)*grad(u))*(Inv(F.trans)*grad(v))-f*v)*J*dx
#    return ( (Finv.trans*grad(u))*(Finv.trans*grad(v))-f*v)*J*dx

def CostAuto(u): 
    return J*(u-ud)**q*dx

# %%
VEC = H1(mesh, order=2, dim=2)
PHI, X = VEC.TnT()

Lagrangian = CostAuto(gfu) + Equation(gfu,gfp)
dJOmegaAuto = LinearForm(VEC)
dJOmegaAuto += Lagrangian.Diff(J, div(X))
dJOmegaAuto += Lagrangian.Diff(F, grad(X).trans)   # grad(X).trans is Jacobian
dJOmegaAuto += Lagrangian.Diff(x, X[0]) + Lagrangian.Diff(y, X[1])

# %%
b = BilinearForm(VEC)
b += InnerProduct(grad(X),grad(PHI))*dx + InnerProduct(X,PHI)*dx

gfX = GridFunction(VEC)

# %%
def SolveDeformationEquationAuto():
    rhs = gfX.vec.CreateVector()
    rhs.data = dJOmegaAuto.vec - b.mat * gfX.vec
    update = gfX.vec.CreateVector()
    update.data = b.mat.Inverse(VEC.FreeDofs()) * rhs
    gfX.vec.data += update

# %%
b.Assemble()
dJOmegaAuto.Assemble()
SolveDeformationEquationAuto()
Draw(-gfX, mesh, "gfX")
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2201', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, 'draw_vol': Fals…
# BaseWebGuiScene

# %%
# gfset denotes the deformation of the original domain and will be updated during the shape optimization
gfset = GridFunction(VEC)
gfset.Set((0,0))
mesh.SetDeformation(gfset)
sceneSet = Draw(gfset,mesh,"gfset")
SetVisualization (deformation=True)
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2201', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, 'draw_vol': Fals…

# %%
gfset.Set((0,0))
mesh.SetDeformation(gfset)
print('Cost at initial design', Integrate (CostAuto(gfu), mesh))

scale = 0.5 / Norm(gfX.vec)
gfset.vec.data -= scale * gfX.vec
mesh.SetDeformation(gfset)
sceneSet.Redraw()
# Out:
# Cost at initial design 3.424780558662707e-09

# %%
a.Assemble()
fstate.Assemble()
SolveStateEquation()
print('Cost at new design', Integrate (CostAuto(gfu), mesh))
# Out:
# Cost at new design 1.0575735360481383e-08

# %% [markdown]
# Equation can also be used to define the bilinear form. The following defines the same bilinear form as above:

# %%
aAuto = BilinearForm(fes, symmetric=True)
aAuto += Equation(u,v)

# %% [markdown]
# Thus, the user has to enter the PDE (in its transformed form) only once.

# %% [markdown]
# Finally, let us again run the full algorithm:

# %%
#reset to and solve for initial configuration
gfset.Set((0,0))
mesh.SetDeformation(gfset)
scene = Draw(gfset,mesh,"gfset")
SetVisualization (deformation=True)

a.Assemble()
fstate.Assemble()
SolveStateEquation()

LineSearch = False

iter_max = 600
Jold = Integrate(CostAuto(gfu), mesh)
converged = False
for k in range(iter_max):
    scene.Redraw()
    print('cost at iteration', k, ': ', Jold)
    mesh.SetDeformation(gfset)
    
    a.Assemble()
    fstate.Assemble()
    SolveStateEquation()
    
    fadjoint.Assemble()
    SolveAdjointEquation()
    
    b.Assemble()
    dJOmegaAuto.Assemble()
    SolveDeformationEquationAuto()

    scale = 0.01 / Norm(gfX.vec)
    gfsetOld = gfset
    gfset.vec.data -= scale * gfX.vec
    
    Jnew = Integrate(CostAuto(gfu), mesh)
    
    if LineSearch:
        while Jnew > Jold and scale > 1e-12:
            scale = scale / 2
            
            if scale <= 1e-12:
                converged = True
                break

            gfset.vec.data = gfsetOld.vec - scale * gfX.vec
            mesh.SetDeformation(gfset)
            
            a.Assemble()
            fstate.Assemble()
            SolveStateEquation()
            Jnew = Integrate(CostAuto(gfu), mesh)
    
    if converged==True:
        break
    Jold = Jnew
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2201', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, 'draw_vol': Fals…
# cost at iteration 0 :  5.15224413081495e-09
# cost at iteration 1 :  4.942040315052451e-09
# cost at iteration 2 :  4.585080869047023e-09
# cost at iteration 3 :  4.2494398855982596e-09
# cost at iteration 4 :  3.934229274496257e-09
# cost at iteration 5 :  3.6385740544274712e-09
# cost at iteration 6 :  3.3616132927088315e-09
# cost at iteration 7 :  3.102501038477645e-09
# cost at iteration 8 :  2.8604072470352585e-09
# cost at iteration 9 :  2.63451869268272e-09
# cost at iteration 10 :  2.424039866929766e-09
# cost at iteration 11 :  2.228193858360781e-09
# cost at iteration 12 :  2.046223209662374e-09
# cost at iteration 13 :  1.8773907462767712e-09
# cost at iteration 14 :  1.720980369755032e-09
# cost at iteration 15 :  1.5762978070056823e-09
# cost at iteration 16 :  1.4426713040877704e-09
# cost at iteration 17 :  1.3194522497306292e-09
# cost at iteration 18 :  1.2060157090339143e-09
# cost at iteration 19 :  1.101760841345096e-09
# cost at iteration 20 :  1.0061111674975617e-09
# cost at iteration 21 :  9.185146395774454e-10
# cost at iteration 22 :  8.384434500547991e-10
# cost at iteration 23 :  7.653934950250692e-10
# cost at iteration 24 :  6.988833766917691e-10
# cost at iteration 25 :  6.384527911306823e-10
# cost at iteration 26 :  5.836600972575327e-10
# cost at iteration 27 :  5.340788023199242e-10
# cost at iteration 28 :  4.892926352905073e-10
# cost at iteration 29 :  4.4888883727719345e-10
# cost at iteration 30 :  4.1244934756444957e-10
# cost at iteration 31 :  3.7953988216765983e-10
# cost at iteration 32 :  3.496978994973493e-10
# cost at iteration 33 :  3.224229646055938e-10
# cost at iteration 34 :  2.971783343356934e-10
# cost at iteration 35 :  2.7342084971814884e-10
# cost at iteration 36 :  2.5067980475045674e-10
# cost at iteration 37 :  2.286786524892596e-10
# cost at iteration 38 :  2.0741877930875077e-10
# cost at iteration 39 :  1.8711564698267467e-10
# cost at iteration 40 :  1.680225990721037e-10
# cost at iteration 41 :  1.5030409913780605e-10
# cost at iteration 42 :  1.340169892860868e-10
# cost at iteration 43 :  1.1914272597739685e-10
# cost at iteration 44 :  1.0562118891348397e-10
# cost at iteration 45 :  9.337291061389818e-11
# cost at iteration 46 :  8.231145824835342e-11
# cost at iteration 47 :  7.234975395316619e-11
# cost at iteration 48 :  6.340308482728853e-11
# cost at iteration 49 :  5.5390421616271224e-11
# cost at iteration 50 :  4.8234916729450734e-11
# cost at iteration 51 :  4.186402390638014e-11
# cost at iteration 52 :  3.620945390576394e-11
# cost at iteration 53 :  3.120706538020545e-11
# cost at iteration 54 :  2.6796734440610493e-11
# cost at iteration 55 :  2.2922220688921773e-11
# cost at iteration 56 :  1.9531036130474338e-11
# cost at iteration 57 :  1.6574318562732695e-11
# cost at iteration 58 :  1.4006709060443813e-11
# cost at iteration 59 :  1.178623236232479e-11
# cost at iteration 60 :  9.874178616579012e-12
# cost at iteration 61 :  8.234984789861506e-12
# cost at iteration 62 :  6.83611401949906e-12
# cost at iteration 63 :  5.647931255554232e-12
# cost at iteration 64 :  4.643573755014198e-12
# cost at iteration 65 :  3.798815274469229e-12
# cost at iteration 66 :  3.091923364161052e-12
# cost at iteration 67 :  2.503509546390779e-12
# cost at iteration 68 :  2.0163733803415606e-12
# cost at iteration 69 :  1.6153408579924357e-12
# cost at iteration 70 :  1.287101850968642e-12
# cost at iteration 71 :  1.0200425647020584e-12
# cost at iteration 72 :  8.041018664772039e-13
# cost at iteration 73 :  6.306631093768677e-13
# cost at iteration 74 :  4.937897990679307e-13
# cost at iteration 75 :  4.039544746633963e-13
# cost at iteration 76 :  3.698763015166262e-13
# cost at iteration 77 :  3.3922603687275384e-13
# cost at iteration 78 :  3.1002998939736485e-13
# cost at iteration 79 :  2.8425405555239154e-13
# cost at iteration 80 :  2.602673386868327e-13
# cost at iteration 81 :  2.3875897848720257e-13
# cost at iteration 82 :  2.1899256044837592e-13
# cost at iteration 83 :  2.011172742589962e-13
# cost at iteration 84 :  1.8479779449585422e-13
# cost at iteration 85 :  1.6997086635476432e-13
# cost at iteration 86 :  1.5648035215145026e-13
# cost at iteration 87 :  1.44190591048302e-13
# cost at iteration 88 :  1.3302550619103806e-13
# cost at iteration 89 :  1.2283568487555082e-13
# cost at iteration 90 :  1.1358057268614736e-13
# cost at iteration 91 :  1.0512052397187497e-13
# cost at iteration 92 :  9.743049675983373e-14
# cost at iteration 93 :  9.038906457123637e-14
# cost at iteration 94 :  8.397780568895653e-14
# cost at iteration 95 :  7.809555199437352e-14
# cost at iteration 96 :  7.272662122485635e-14
# cost at iteration 97 :  6.778940646266967e-14
# cost at iteration 98 :  6.326927799623977e-14
# cost at iteration 99 :  5.910231771742867e-14
# cost at iteration 100 :  5.527417828592784e-14
# cost at iteration 101 :  5.17362911086346e-14
# cost at iteration 102 :  4.84741989159851e-14
# cost at iteration 103 :  4.545224780224193e-14
# cost at iteration 104 :  4.265565705497683e-14
# cost at iteration 105 :  4.005937321331225e-14
# cost at iteration 106 :  3.764819407632815e-14
# cost at iteration 107 :  3.540559194657983e-14
# cost at iteration 108 :  3.331593759012794e-14
# cost at iteration 109 :  3.136944273169338e-14
# cost at iteration 110 :  2.955012019270663e-14
# cost at iteration 111 :  2.785342462781246e-14
# cost at iteration 112 :  2.6263134638509994e-14
# cost at iteration 113 :  2.4778715920653707e-14
# cost at iteration 114 :  2.338387112723431e-14
# cost at iteration 115 :  2.2081073106856825e-14
# cost at iteration 116 :  2.0854124133833026e-14
# cost at iteration 117 :  1.9707689943771766e-14
# cost at iteration 118 :  1.862585232334556e-14
# cost at iteration 119 :  1.76148099611054e-14
# cost at iteration 120 :  1.665909955581205e-14
# cost at iteration 121 :  1.5765916517315827e-14
# cost at iteration 122 :  1.4920417392097404e-14
# cost at iteration 123 :  1.4130354898788702e-14
# cost at iteration 124 :  1.3381653955433815e-14
# cost at iteration 125 :  1.2682255225771813e-14
# cost at iteration 126 :  1.2018973231932252e-14
# cost at iteration 127 :  1.1399604754094184e-14
# cost at iteration 128 :  1.0811928869397096e-14
# cost at iteration 129 :  1.0263269286636977e-14
# cost at iteration 130 :  9.742393351103332e-15
# cost at iteration 131 :  9.25583517987821e-15
# cost at iteration 132 :  8.79340108946507e-15
# cost at iteration 133 :  8.360648124465474e-15
# cost at iteration 134 :  7.948629293295526e-15
# cost at iteration 135 :  7.561940973401028e-15
# cost at iteration 136 :  7.193162142948924e-15
# cost at iteration 137 :  6.8459882247524446e-15
# cost at iteration 138 :  6.5146293353777406e-15
# cost at iteration 139 :  6.201853132909496e-15
# cost at iteration 140 :  5.90340483649491e-15
# cost at iteration 141 :  5.6210754765986024e-15
# cost at iteration 142 :  5.351975536145427e-15
# cost at iteration 143 :  5.0969193492776986e-15
# cost at iteration 144 :  4.854216203554065e-15
# cost at iteration 145 :  4.62375564272815e-15
# cost at iteration 146 :  4.4048983426775065e-15
# cost at iteration 147 :  4.1966913962065214e-15
# cost at iteration 148 :  3.999415392819389e-15
# cost at iteration 149 :  3.8113696987687075e-15
# cost at iteration 150 :  3.63363512585722e-15
# cost at iteration 151 :  3.4638602024741007e-15
# cost at iteration 152 :  3.3038153490104495e-15
# cost at iteration 153 :  3.1505927383374927e-15
# cost at iteration 154 :  3.0065488192760925e-15
# cost at iteration 155 :  2.8683105735376126e-15
# cost at iteration 156 :  2.7387217250849668e-15
# cost at iteration 157 :  2.614034124502121e-15
# cost at iteration 158 :  2.4974820143215944e-15
# cost at iteration 159 :  2.3850385471912695e-15
# cost at iteration 160 :  2.280231064517658e-15
# cost at iteration 161 :  2.1788814159329295e-15
# cost at iteration 162 :  2.084720284442006e-15
# cost at iteration 163 :  1.993680681071457e-15
# cost at iteration 164 :  1.909710686149311e-15
# cost at iteration 165 :  1.829692844967472e-15
# cost at iteration 166 :  1.7578866584256496e-15
# cost at iteration 167 :  1.6920685658792878e-15
# cost at iteration 168 :  1.6308868944734509e-15
# cost at iteration 169 :  1.5727770961564407e-15
# cost at iteration 170 :  1.5163629515915367e-15
# cost at iteration 171 :  1.4630065466012588e-15
# cost at iteration 172 :  1.4108653858238726e-15
# cost at iteration 173 :  1.3617870594509957e-15
# cost at iteration 174 :  1.3138860889410152e-15
# cost at iteration 175 :  1.2689311516197834e-15
# cost at iteration 176 :  1.2251470143890144e-15
# cost at iteration 177 :  1.1841462497255839e-15
# cost at iteration 178 :  1.1442841435162155e-15
# cost at iteration 179 :  1.1070185537304874e-15
# cost at iteration 180 :  1.070831382034867e-15
# cost at iteration 181 :  1.0370412509444706e-15
# cost at iteration 182 :  1.0042496550676848e-15
# cost at iteration 183 :  9.736518554055357e-16
# cost at iteration 184 :  9.439624454810348e-16
# cost at iteration 185 :  9.162666770210437e-16
# cost at iteration 186 :  8.893865615339492e-16
# cost at iteration 187 :  8.643079784914744e-16
# cost at iteration 188 :  8.399552001149714e-16
# cost at iteration 189 :  8.172231407771183e-16
# cost at iteration 190 :  7.951334285042868e-16
# cost at iteration 191 :  7.744967529300874e-16
# cost at iteration 192 :  7.544272998804951e-16
# cost at iteration 193 :  7.356570713298268e-16
# cost at iteration 194 :  7.173880864613703e-16
# cost at iteration 195 :  7.00278327070477e-16
# cost at iteration 196 :  6.83613029721906e-16
# cost at iteration 197 :  6.679801795033252e-16
# cost at iteration 198 :  6.527437831609684e-16
# cost at iteration 199 :  6.384253594385948e-16
# cost at iteration 200 :  6.244634630658484e-16
# cost at iteration 201 :  6.113162879693905e-16
# cost at iteration 202 :  5.984929775835633e-16
# cost at iteration 203 :  5.863912297165368e-16
# cost at iteration 204 :  5.74587097015221e-16
# cost at iteration 205 :  5.634203550943045e-16
# cost at iteration 206 :  5.525305653951809e-16
# cost at iteration 207 :  5.422019459643741e-16
# cost at iteration 208 :  5.321344329154671e-16
# cost at iteration 209 :  5.22558877869365e-16
# cost at iteration 210 :  5.132327041437418e-16
# cost at iteration 211 :  5.043354426357673e-16
# cost at iteration 212 :  4.956793405227121e-16
# cost at iteration 213 :  4.873945299671887e-16
# cost at iteration 214 :  4.793456200117412e-16
# cost at iteration 215 :  4.7161515902346755e-16
# cost at iteration 216 :  4.641178358006617e-16
# cost at iteration 217 :  4.568903354886358e-16
# cost at iteration 218 :  4.498953050259664e-16
# cost at iteration 219 :  4.431252021791927e-16
# cost at iteration 220 :  4.3658865384638224e-16
# cost at iteration 221 :  4.302354488810193e-16
# cost at iteration 222 :  4.241183446222297e-16
# cost at iteration 223 :  4.18145947787199e-16
# cost at iteration 224 :  4.1241341261551005e-16
# cost at iteration 225 :  4.067895832760085e-16
# cost at iteration 226 :  4.0141038248630387e-16
# cost at iteration 227 :  3.961062479355859e-16
# cost at iteration 228 :  3.9105233820982305e-16
# cost at iteration 229 :  3.860419801642996e-16
# cost at iteration 230 :  3.8128812345491837e-16
# cost at iteration 231 :  3.7654822202830126e-16
# cost at iteration 232 :  3.7207165270782437e-16
# cost at iteration 233 :  3.6758117916440903e-16
# cost at iteration 234 :  3.6336131637081475e-16
# cost at iteration 235 :  3.591012672935517e-16
# cost at iteration 236 :  3.5511946566322927e-16
# cost at iteration 237 :  3.5107263233250296e-16
# cost at iteration 238 :  3.4731196539715065e-16
# cost at iteration 239 :  3.4346273316655854e-16
# cost at iteration 240 :  3.399078046099403e-16
# cost at iteration 241 :  3.3624197790293675e-16
# cost at iteration 242 :  3.3287875664490084e-16
# cost at iteration 243 :  3.2938340589679376e-16
# cost at iteration 244 :  3.2619908161594367e-16
# cost at iteration 245 :  3.2286240907007217e-16
# cost at iteration 246 :  3.1984526531112124e-16
# cost at iteration 247 :  3.166564870632567e-16
# cost at iteration 248 :  3.137957895190757e-16
# cost at iteration 249 :  3.107450316062348e-16
# cost at iteration 250 :  3.0803092953269456e-16
# cost at iteration 251 :  3.051091361970659e-16
# cost at iteration 252 :  3.0253257522492257e-16
# cost at iteration 253 :  2.9973142776093066e-16
# cost at iteration 254 :  2.97284072624241e-16
# cost at iteration 255 :  2.945959174489106e-16
# cost at iteration 256 :  2.922700833627077e-16
# cost at iteration 257 :  2.8968786814304137e-16
# cost at iteration 258 :  2.874764597426157e-16
# cost at iteration 259 :  2.8499367657686703e-16
# cost at iteration 260 :  2.828901334818541e-16
# cost at iteration 261 :  2.805007682689928e-16
# cost at iteration 262 :  2.7849901646384364e-16
# cost at iteration 263 :  2.761975037120319e-16
# cost at iteration 264 :  2.7429191204296403e-16
# cost at iteration 265 :  2.7207309446713297e-16
# cost at iteration 266 :  2.7025843564884126e-16
# cost at iteration 267 :  2.6811752799198115e-16
# cost at iteration 268 :  2.6638894359637424e-16
# cost at iteration 269 :  2.643215001821108e-16
# cost at iteration 270 :  2.6267446914993046e-16
# cost at iteration 271 :  2.606763547359105e-16
# cost at iteration 272 :  2.59106665010388e-16
# cost at iteration 273 :  2.5717402856633534e-16
# cost at iteration 274 :  2.556777514986227e-16
# cost at iteration 275 :  2.538070025793883e-16
# cost at iteration 276 :  2.5238046979907904e-16
# cost at iteration 277 :  2.5056825722313173e-16
# cost at iteration 278 :  2.4920803970496017e-16
# cost at iteration 279 :  2.4745123228427995e-16
# cost at iteration 280 :  2.461541213746822e-16
# cost at iteration 281 :  2.4444979047220834e-16
# cost at iteration 282 :  2.432127806676219e-16
# cost at iteration 283 :  2.415581843853057e-16
# cost at iteration 284 :  2.4037845767903356e-16
# cost at iteration 285 :  2.387710265025579e-16
# cost at iteration 286 :  2.3764593813808436e-16
# cost at iteration 287 :  2.3608326188478206e-16
# cost at iteration 288 :  2.350103273723477e-16
# cost at iteration 289 :  2.3349014330671386e-16
# cost at iteration 290 :  2.324670265759704e-16
# cost at iteration 291 :  2.3098720857259923e-16
# cost at iteration 292 :  2.3001171114885724e-16
# cost at iteration 293 :  2.28570259796425e-16
# cost at iteration 294 :  2.2764031089992077e-16
# cost at iteration 295 :  2.262353444519282e-16
# cost at iteration 296 :  2.2534899193093097e-16
# cost at iteration 297 :  2.2397873801936736e-16
# cost at iteration 298 :  2.2313414003735235e-16
# cost at iteration 299 :  2.2179692807479887e-16
# cost at iteration 300 :  2.2099234548042198e-16
# cost at iteration 301 :  2.1968659968438207e-16
# cost at iteration 302 :  2.1892038900054116e-16
# cost at iteration 303 :  2.1764462198082799e-16
# cost at iteration 304 :  2.1691522895552603e-16
# cost at iteration 305 :  2.156680358121132e-16
# cost at iteration 306 :  2.1497398947993057e-16
# cost at iteration 307 :  2.1375404236414108e-16
# cost at iteration 308 :  2.1309394957211544e-16
# cost at iteration 309 :  2.1189999266897416e-16
# cost at iteration 310 :  2.1127253302541496e-16
# cost at iteration 311 :  2.1010337791962133e-16
# cost at iteration 312 :  2.095072991284053e-16
# cost at iteration 313 :  2.0836182051975303e-16
# cost at iteration 314 :  2.0779593406647802e-16
# cost at iteration 315 :  2.066730658047053e-16
# cost at iteration 316 :  2.0613624296408884e-16
# cost at iteration 317 :  2.050349743754011e-16
# cost at iteration 318 :  2.0452614251253307e-16
# cost at iteration 319 :  2.034455149934021e-16
# cost at iteration 320 :  2.0296365413382787e-16
# cost at iteration 321 :  2.0190275798964114e-16
# cost at iteration 322 :  2.014468976358187e-16
# cost at iteration 323 :  2.0040486914431227e-16
# cost at iteration 324 :  1.9997408531787449e-16
# cost at iteration 325 :  1.9895010399904466e-16
# cost at iteration 326 :  1.9854351649046803e-16
# cost at iteration 327 :  1.9753680256650372e-16
# cost at iteration 328 :  1.9715357237522778e-16
# cost at iteration 329 :  1.961633844053148e-16
# cost at iteration 330 :  1.9580271135499095e-16
# cost at iteration 331 :  1.9482834403142537e-16
# cost at iteration 332 :  1.9448946454657003e-16
# cost at iteration 333 :  1.935302466395936e-16
# cost at iteration 334 :  1.9321243167075003e-16
# cost at iteration 335 :  1.9226772411081833e-16
# cost at iteration 336 :  1.9197027719684188e-16
# cost at iteration 337 :  1.910394712839385e-16
# cost at iteration 338 :  1.9076172674079576e-16
# cost at iteration 339 :  1.898442424711472e-16
# cost at iteration 340 :  1.8958556369777374e-16
# cost at iteration 341 :  1.8868084819938846e-16
# cost at iteration 342 :  1.8844062609162912e-16
# cost at iteration 343 :  1.875481521606054e-16
# cost at iteration 344 :  1.8732580362544514e-16
# cost at iteration 345 :  1.8644506835566476e-16
# cost at iteration 346 :  1.8624003491831948e-16
# cost at iteration 347 :  1.8537055841780763e-16
# cost at iteration 348 :  1.8518230491494444e-16
# cost at iteration 349 :  1.843236291026603e-16
# cost at iteration 350 :  1.84151642455656e-16
# cost at iteration 351 :  1.833033299330789e-16
# cost at iteration 352 :  1.8314711799565176e-16
# cost at iteration 353 :  1.8230875098764145e-16
# cost at iteration 354 :  1.8216784146271312e-16
# cost at iteration 355 :  1.81339020823104e-16
# cost at iteration 356 :  1.8121296024402017e-16
# cost at iteration 357 :  1.8039330452114586e-16
# cost at iteration 358 :  1.8028165729302855e-16
# cost at iteration 359 :  1.7947080185121214e-16
# cost at iteration 360 :  1.7937314934829296e-16
# cost at iteration 361 :  1.785707455413949e-16
# cost at iteration 362 :  1.7848668525666622e-16
# cost at iteration 363 :  1.776923996501491e-16
# cost at iteration 364 :  1.7762154439381888e-16
# cost at iteration 365 :  1.7683505803202424e-16
# cost at iteration 366 :  1.7677703517575254e-16
# cost at iteration 367 :  1.759980428912923e-16
# cost at iteration 368 :  1.7595249365510846e-16
# cost at iteration 369 :  1.751807034177286e-16
# cost at iteration 370 :  1.7514728219703683e-16
# cost at iteration 371 :  1.7438241449912228e-16
# cost at iteration 372 :  1.7436078822912926e-16
# cost at iteration 373 :  1.736025755055876e-16
# cost at iteration 374 :  1.7359242306100448e-16
# cost at iteration 375 :  1.7284060914117912e-16
# cost at iteration 376 :  1.7284162076889426e-16
# cost at iteration 377 :  1.7209596035845254e-16
# cost at iteration 378 :  1.721078371411728e-16
# cost at iteration 379 :  1.7136809533210128e-16
# cost at iteration 380 :  1.7139054868107908e-16
# cost at iteration 381 :  1.7065650048792722e-16
# cost at iteration 382 :  1.7068925166313815e-16
# cost at iteration 383 :  1.6996068158373617e-16
# cost at iteration 384 :  1.7000346123967955e-16
# cost at iteration 385 :  1.6928016283906608e-16
# cost at iteration 386 :  1.6933271059481908e-16
# cost at iteration 387 :  1.686144861106365e-16
# cost at iteration 388 :  1.6867655014270175e-16
# cost at iteration 389 :  1.6796321011089832e-16
# cost at iteration 390 :  1.6803454676747e-16
# cost at iteration 391 :  1.6732590966705055e-16
# cost at iteration 392 :  1.6740628310253625e-16
# cost at iteration 393 :  1.6670217501807328e-16
# cost at iteration 394 :  1.667913568466423e-16
# cost at iteration 395 :  1.6609161114768485e-16
# cost at iteration 396 :  1.6618938011480133e-16
# cost at iteration 397 :  1.6549383715098301e-16
# cost at iteration 398 :  1.655999788218116e-16
# cost at iteration 399 :  1.6490848563282042e-16
# cost at iteration 400 :  1.650227920967897e-16
# cost at iteration 401 :  1.6433520213630921e-16
# cost at iteration 402 :  1.6445747172653034e-16
# cost at iteration 403 :  1.6377364459937675e-16
# cost at iteration 404 :  1.6390368162652313e-16
# cost at iteration 405 :  1.6322348283811772e-16
# cost at iteration 406 :  1.6336109733761319e-16
# cost at iteration 407 :  1.6268439805523552e-16
# cost at iteration 408 :  1.6282940554722989e-16
# cost at iteration 409 :  1.6215608237222906e-16
# cost at iteration 410 :  1.6230830363357555e-16
# cost at iteration 411 :  1.6163823838411233e-16
# cost at iteration 412 :  1.6179749923168332e-16
# cost at iteration 413 :  1.6113057873516334e-16
# cost at iteration 414 :  1.6129670981990853e-16
# cost at iteration 415 :  1.606328257149223e-16
# cost at iteration 416 :  1.6080566232608115e-16
# cost at iteration 417 :  1.6014471087299072e-16
# cost at iteration 418 :  1.6032409275191715e-16
# cost at iteration 419 :  1.596659746518778e-16
# cost at iteration 420 :  1.5985174581493895e-16
# cost at iteration 421 :  1.5919636603677917e-16
# cost at iteration 422 :  1.5938837460687211e-16
# cost at iteration 423 :  1.5873564222145145e-16
# cost at iteration 424 :  1.5893374026763346e-16
# cost at iteration 425 :  1.5828356828936987e-16
# cost at iteration 426 :  1.5848761167423031e-16
# cost at iteration 427 :  1.5783991690926845e-16
# cost at iteration 428 :  1.580497651435407e-16
# cost at iteration 429 :  1.5740446804439172e-16
# cost at iteration 430 :  1.5761998414857623e-16
# cost at iteration 431 :  1.5697700867474845e-16
# cost at iteration 432 :  1.5719805904721382e-16
# cost at iteration 433 :  1.5655733253173887e-16
# cost at iteration 434 :  1.5678378682299172e-16
# cost at iteration 435 :  1.5614523984434954e-16
# cost at iteration 436 :  1.5637697083732955e-16
# cost at iteration 437 :  1.5574053709657108e-16
# cost at iteration 438 :  1.559774205923761e-16
# cost at iteration 439 :  1.5534303679536826e-16
# cost at iteration 440 :  1.555849515043276e-16
# cost at iteration 441 :  1.5495255724855778e-16
# cost at iteration 442 :  1.551993846863536e-16
# cost at iteration 443 :  1.545689223523761e-16
# cost at iteration 444 :  1.548205467408535e-16
# cost at iteration 445 :  1.5419196138799673e-16
# cost at iteration 446 :  1.5444826956050187e-16
# cost at iteration 447 :  1.5382150882668902e-16
# cost at iteration 448 :  1.5408239013775089e-16
# cost at iteration 449 :  1.5345740414321172e-16
# cost at iteration 450 :  1.5372275038220206e-16
# cost at iteration 451 :  1.530994916369627e-16
# cost at iteration 452 :  1.5336919694568767e-16
# cost at iteration 453 :  1.5274762026066006e-16
# cost at iteration 454 :  1.5302158105452917e-16
# cost at iteration 455 :  1.5240164345594213e-16
# cost at iteration 456 :  1.5267975834873312e-16
# cost at iteration 457 :  1.5206141899587704e-16
# cost at iteration 458 :  1.5234358872764903e-16
# cost at iteration 459 :  1.5172680883378724e-16
# cost at iteration 460 :  1.5201293620209656e-16
# cost at iteration 461 :  1.5139767895824346e-16
# cost at iteration 462 :  1.5168766875222681e-16
# cost at iteration 463 :  1.5107389925393738e-16
# cost at iteration 464 :  1.5136765819126223e-16
# cost at iteration 465 :  1.5075534336804596e-16
# cost at iteration 466 :  1.5105278003458435e-16
# cost at iteration 467 :  1.5044188858198275e-16
# cost at iteration 468 :  1.5074291337398802e-16
# cost at iteration 469 :  1.5013341568820705e-16
# cost at iteration 470 :  1.5043794075699996e-16
# cost at iteration 471 :  1.4982980887189185e-16
# cost at iteration 472 :  1.501377480707707e-16
# cost at iteration 473 :  1.4953095559718177e-16
# cost at iteration 474 :  1.4984222443061832e-16
# cost at iteration 475 :  1.4923674649790504e-16
# cost at iteration 476 :  1.4955126207281131e-16
# cost at iteration 477 :  1.4894707527251803e-16
# cost at iteration 478 :  1.4926475625148776e-16
# cost at iteration 479 :  1.4866183858306756e-16
# cost at iteration 480 :  1.4898260513956392e-16
# cost at iteration 481 :  1.4838093595805383e-16
# cost at iteration 482 :  1.487047097333142e-16
# cost at iteration 483 :  1.481042696988694e-16
# cost at iteration 484 :  1.4843097376067593e-16
# cost at iteration 485 :  1.4783174478996964e-16
# cost at iteration 486 :  1.4816130359292393e-16
# cost at iteration 487 :  1.47563268812234e-16
# cost at iteration 488 :  1.4789560815968123e-16
# cost at iteration 489 :  1.4729875185968377e-16
# cost at iteration 490 :  1.4763379886706417e-16
# cost at iteration 491 :  1.4703810645919668e-16
# cost at iteration 492 :  1.4737578951888703e-16
# cost at iteration 493 :  1.4678124749332586e-16
# cost at iteration 494 :  1.471214962407711e-16
# cost at iteration 495 :  1.465280921257814e-16
# cost at iteration 496 :  1.4687083740696887e-16
# cost at iteration 497 :  1.462785597298181e-16
# cost at iteration 498 :  1.4662373356992697e-16
# cost at iteration 499 :  1.4603257181904724e-16
# cost at iteration 500 :  1.463801073923345e-16
# cost at iteration 501 :  1.4579005198095466e-16
# cost at iteration 502 :  1.4613988358169514e-16
# cost at iteration 503 :  1.455509258125696e-16
# cost at iteration 504 :  1.45902988827138e-16
# cost at iteration 505 :  1.4531512085866654e-16
# cost at iteration 506 :  1.456693517385895e-16
# cost at iteration 507 :  1.4508256655201822e-16
# cost at iteration 508 :  1.4543890278802015e-16
# cost at iteration 509 :  1.4485319415582594e-16
# cost at iteration 510 :  1.4521157425277765e-16
# cost at iteration 511 :  1.4462693670814434e-16
# cost at iteration 512 :  1.449873001609502e-16
# cost at iteration 513 :  1.4440372896831352e-16
# cost at iteration 514 :  1.4476601623861788e-16
# cost at iteration 515 :  1.441835073651495e-16
# cost at iteration 516 :  1.4454765985886968e-16
# cost at iteration 517 :  1.4396620994711071e-16
# cost at iteration 518 :  1.4433216999270094e-16
# cost at iteration 519 :  1.4375177633394042e-16
# cost at iteration 520 :  1.4411948716148512e-16
# cost at iteration 521 :  1.4354014767021896e-16
# cost at iteration 522 :  1.439095533911659e-16
# cost at iteration 523 :  1.4333126658033666e-16
# cost at iteration 524 :  1.4370231216790504e-16
# cost at iteration 525 :  1.4312507712505409e-16
# cost at iteration 526 :  1.434977083953539e-16
# cost at iteration 527 :  1.4292152475953006e-16
# cost at iteration 528 :  1.4329568835324866e-16
# cost at iteration 529 :  1.4272055629277298e-16
# cost at iteration 530 :  1.430961996574744e-16
# cost at iteration 531 :  1.4252211984844159e-16
# cost at iteration 532 :  1.4289919122142385e-16
# cost at iteration 533 :  1.4232616482692161e-16
# cost at iteration 534 :  1.4270461321865533e-16
# cost at iteration 535 :  1.4213264186872628e-16
# cost at iteration 536 :  1.4251241704678467e-16
# cost at iteration 537 :  1.4194150281903701e-16
# cost at iteration 538 :  1.4232255529253583e-16
# cost at iteration 539 :  1.4175270069346309e-16
# cost at iteration 540 :  1.4213498169797224e-16
# cost at iteration 541 :  1.415661896449016e-16
# cost at iteration 542 :  1.4194965112783957e-16
# cost at iteration 543 :  1.4138192493145096e-16
# cost at iteration 544 :  1.4176651953788478e-16
# cost at iteration 545 :  1.4119986288540961e-16
# cost at iteration 546 :  1.4158554394433304e-16
# cost at iteration 547 :  1.4101996088324467e-16
# cost at iteration 548 :  1.4140668239421488e-16
# cost at iteration 549 :  1.4084217731654876e-16
# cost at iteration 550 :  1.412298939367084e-16
# cost at iteration 551 :  1.406664715638653e-16
# cost at iteration 552 :  1.410551385953921e-16
# cost at iteration 553 :  1.4049280396351039e-16
# cost at iteration 554 :  1.408823773413676e-16
# cost at iteration 555 :  1.4032113578717723e-16
# cost at iteration 556 :  1.4071157206724536e-16
# cost at iteration 557 :  1.4015142921435428e-16
# cost at iteration 558 :  1.4054268556188607e-16
# cost at iteration 559 :  1.3998364730765118e-16
# cost at iteration 560 :  1.4037568148604285e-16
# cost at iteration 561 :  1.3981775398879767e-16
# cost at iteration 562 :  1.4021052434867176e-16
# cost at iteration 563 :  1.396537140154319e-16
# cost at iteration 564 :  1.4004717948397898e-16
# cost at iteration 565 :  1.3949149295857619e-16
# cost at iteration 566 :  1.398856130292583e-16
# cost at iteration 567 :  1.393310571808505e-16
# cost at iteration 568 :  1.3972579190329669e-16
# cost at iteration 569 :  1.3917237381534913e-16
# cost at iteration 570 :  1.3956768378554781e-16
# cost at iteration 571 :  1.390154107450995e-16
# cost at iteration 572 :  1.3941125709584033e-16
# cost at iteration 573 :  1.3886013658324103e-16
# cost at iteration 574 :  1.3925648097481658e-16
# cost at iteration 575 :  1.387065206537343e-16
# cost at iteration 576 :  1.3910332526485305e-16
# cost at iteration 577 :  1.3855453297267518e-16
# cost at iteration 578 :  1.389517604915901e-16
# cost at iteration 579 :  1.3840414423016606e-16
# cost at iteration 580 :  1.3880175784605618e-16
# cost at iteration 581 :  1.3825532577277443e-16
# cost at iteration 582 :  1.3865328916731555e-16
# cost at iteration 583 :  1.3810804958640873e-16
# cost at iteration 584 :  1.3850632692555095e-16
# cost at iteration 585 :  1.3796228827983073e-16
# cost at iteration 586 :  1.3836084420573226e-16
# cost at iteration 587 :  1.3781801506856868e-16
# cost at iteration 588 :  1.382168146917712e-16
# cost at iteration 589 :  1.3767520375929128e-16
# cost at iteration 590 :  1.380742126510879e-16
# cost at iteration 591 :  1.3753382873472658e-16
# cost at iteration 592 :  1.3793301291964864e-16
# cost at iteration 593 :  1.3739386493897063e-16
# cost at iteration 594 :  1.377931908874578e-16
# cost at iteration 595 :  1.372552878631754e-16
# cost at iteration 596 :  1.376547224844346e-16
# cost at iteration 597 :  1.3711807353173673e-16
# cost at iteration 598 :  1.375175841667614e-16
# cost at iteration 599 :  1.369821984888516e-16
